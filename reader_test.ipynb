# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
from PIL import Image

# %%
img = Image.open("20230504_174000.jpg").convert("RGB")

# %%
img_np = np.array(img)

# %%
plt.imshow(img)

# %%
img_rs = img.resize((1920,1080))

"""
resize에 의한 왜곡 혹은 다른 perspective view 에 대한 왜곡을 잡기 위해서 4개 파란점의 중심을 기준으로 해서 보정 진행.
"""

# %%
plt.imshow(img_rs)
plt.scatter(1570,570)
img_np = np.array(img_rs)

# %%
img_np[570,1570]
# Out:
# array([218, 230, 246], dtype=uint8)

# %%
def color_rgb(k):
    k = k/256
    return (k[0],k[1],k[2])

# %%
cr = color_rgb(img_np[570,1570])
plt.scatter(100,10, c = cr,s=200 )
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
s = []
for i in range(1920*1080):
    a,b = divmod(i,1920)
    s.append( img_np[a,b].tolist() + [a, b ,i]  )

# %%
img_tended = np.array(s)

# %%
for i in img_t:
    x,y = col_pos(i)
    plt.scatter( x,y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-7ad3b21b2122> in <module>
#       1 for i in img_t:
#       2     x,y = col_pos(i)
# ----> 3     plt.scatter( x,y)
#
# ~\Miniconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2846         verts=verts, edgecolors=edgecolors,
#    2847         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2848         None else {}), **kwargs)
#    2849     sci(__ret)
#    2850     return __ret
#
# ~\Miniconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
# ...

# %%
def col_pos (c):
    #3개 짜리 기준으로 만들었지만, 6개가 들어가는 원래 함수가 돌아가도록 되있음. 에러주의
    c_r = np.array([0,1])
    c_g = np.array([0.865,-0.5])
    c_b = np.array([-0.865,-0.5])
    
    return (c[0] * c_r + c[1] *c_g + c[2] * c_b)/256

# %%
col_pos(img_t[0])
# Out:
# array([0.06082031, 0.1796875 ])

# %%
img_t[0]
# Out:
# array([79, 42, 24,  0,  0,  0])
