# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
from PIL import Image

# %%
img = Image.open("20230504_174000.jpg").convert("RGB")

# %%
img_np = np.array(img)

# %%
plt.imshow(img)

# %%
img_rs = img.resize((1920,1080))

# %%
plt.imshow(img_rs)
plt.scatter(1570,570)

# %%
img_np[1570,570]
# Out:
# array([ 97, 105, 118], dtype=uint8)

# %%
def color_rgb(k):
    k = k/256
    return (k[0],k[1],k[2])

# %%
cr = color_rgb(img_np[1570,570])
cr
# Out:
# (0.37890625, 0.41015625, 0.4609375)

# %%
plt.scatter(100,10, c = cr,s=100 )
# Out:
# C:\Users\SSHS\AppData\Local\Temp\ipykernel_12500\2246615889.py:1: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(100,10, c = cr,s=100 )
